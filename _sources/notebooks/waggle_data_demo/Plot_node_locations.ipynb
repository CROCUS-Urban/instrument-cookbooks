# %% [markdown]
# # finding node location for given a period
# We need exact node loaction for analyzing the data. In case of Argonne Deployable Mast (ADM), the location may change on daily basis or during IOP period.
# This notebook demonstrates how to retrieve GPS data for a set of nodes, calculate the mean location for each node, and plot on a map using Folium.

# %%
import sage_data_client.query as query
import folium
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Retrieve and Process GPS Data from Beehive
# lat = values.get("sys.gps.lat")` and `lon = values.get("sys.gps.lon")` extract the mean latitude and longitude values.

# %%
df = query(
    start="2024-07-22T00:00:00Z", 
    end="2024-07-23T03:59:59Z",
    #start = "-5h",
    filter={
        "name": "sys.gps.lat|sys.gps.lon", 
        "vsn": "W09E"
        }
)

df
# Out:
#                                timestamp         name      value  \
# 0    2024-07-22 00:01:25.065691705+00:00  sys.gps.lat  41.867586
# 1    2024-07-22 00:03:24.207831884+00:00  sys.gps.lat  41.867601
# 2    2024-07-22 00:05:25.230349746+00:00  sys.gps.lat  41.867579
# 3    2024-07-22 00:07:25.281453996+00:00  sys.gps.lat  41.867573
# 4    2024-07-22 00:09:24.435063353+00:00  sys.gps.lat  41.867569
# ...                                  ...          ...        ...
# 1663 2024-07-23 03:50:02.456079617+00:00  sys.gps.lon -87.649585
# 1664 2024-07-23 03:52:01.360003752+00:00  sys.gps.lon -87.649615
# 1665 2024-07-23 03:54:02.407563387+00:00  sys.gps.lon -87.649602
# 1666 2024-07-23 03:56:02.498392110+00:00  sys.gps.lon -87.649440
# 1667 2024-07-23 03:58:02.594327687+00:00  sys.gps.lon -87.649537
#
#                        meta.host         meta.node meta.vsn
# 0     000048b02dd3c454.ws-nxcore  000048b02dd3c454     W09E
# 1     000048b02dd3c454.ws-nxcore  000048b02dd3c454     W09E
# 2     000048b02dd3c454.ws-nxcore  000048b02dd3c454     W09E
# 3     000048b02dd3c454.ws-nxcore  000048b02dd3c454     W09E
# 4     000048b02dd3c454.ws-nxcore  000048b02dd3c454     W09E
# ...                          ...               ...      ...
# 1663  000048b02dd3c454.ws-nxcore  000048b02dd3c454     W09E
# 1664  000048b02dd3c454.ws-nxcore  000048b02dd3c454     W09E
# 1665  000048b02dd3c454.ws-nxcore  000048b02dd3c454     W09E
# 1666  000048b02dd3c454.ws-nxcore  000048b02dd3c454     W09E
# 1667  000048b02dd3c454.ws-nxcore  000048b02dd3c454     W09E
#
# [1668 rows x 6 columns]

# %% [markdown]
# Taking mean

# %%
values = df.groupby("name").value.mean()
lat = values.get("sys.gps.lat")
lon = values.get("sys.gps.lon")

# %% [markdown]
# ## Create a map

# %%
m = folium.Map(location=[lat, lon], zoom_start=17)
folium.Marker([lat, lon], popup="ADM").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ef93a1c9f22883566ded8c020746a7f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ef93a1c9f22883566ded8c020746a7f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ef93a1c9f22883566ded8c020746a7f = L.map(
#                 &quot;map_8ef93a1c9f22883566ded8c020746a7f&quot;,
#                 {
#                     center: [41.867571258029976, -87.64957509620264],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43f25b1484db18d56f14cb7d7091f192 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_43f25b1484db18d56f14cb7d7091f192.addTo(map_8ef93a1c9f22883566ded8c020746a7f);
#
#
#             var marker_70e7453699d111eb3701e8884384588d = L.marker(
#                 [41.867571258029976, -87.64957509620264],
#                 {}
#             ).addTo(map_8ef93a1c9f22883566ded8c020746a7f);
#
#
#         var popup_5f2f7d92ecaab5daa098255db8b7789e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_94ffe165fca8f0fb1e5482767132d4c3 = $(`&lt;div id=&quot;html_94ffe165fca8f0fb1e5482767132d4c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ADM&lt;/div&gt;`)[0];
#                 popup_5f2f7d92ecaab5daa098255db8b7789e.setContent(html_94ffe165fca8f0fb1e5482767132d4c3);
#
#
#
#         marker_70e7453699d111eb3701e8884384588d.bindPopup(popup_5f2f7d92ecaab5daa098255db8b7789e)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Now Plotting Mean Locations All Node
# List of CROCUS nodes separated by the "|" .

# %%
node_names = "W0AD|W0AB|W0A5|W0A4|W0A3|W0A2|W0A1|W0A0|W09F|W09E|W09D|W09C|W09B|W09A|W099|W098|W096|W095|W08E|W08D|W08B"
node_list = node_names.split("|")

# %% [markdown]
# We create a Folium map centered on Chicago and set zoom level.

# %%
m = folium.Map(location=[41.8781, -87.6298], zoom_start=10)  # zoom level 10 works best
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_993b9976a437280ba4519cecc919d7f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_993b9976a437280ba4519cecc919d7f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_993b9976a437280ba4519cecc919d7f9 = L.map(
#                 &quot;map_993b9976a437280ba4519cecc919d7f9&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aba0c90da9a8951dd4f6b6112d2a33e6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_aba0c90da9a8951dd4f6b6112d2a33e6.addTo(map_993b9976a437280ba4519cecc919d7f9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df = query(
    start="-24h", 
    #end="2024-07-23T03:59:59Z",
    filter={
        "name": "sys.gps.lat|sys.gps.lon", 
        "vsn": node_names
    }
)
df
# Out:
#                                 timestamp         name      value  \
# 0     2025-02-19 18:04:46.240545911+00:00  sys.gps.lat  41.719876
# 1     2025-02-19 18:06:55.516333796+00:00  sys.gps.lat  41.719868
# 2     2025-02-19 18:08:46.590568027+00:00  sys.gps.lat  41.719878
# 3     2025-02-19 18:10:50.431857144+00:00  sys.gps.lat  41.719878
# 4     2025-02-19 18:12:46.619695426+00:00  sys.gps.lat  41.719834
# ...                                   ...          ...        ...
# 12875 2025-02-20 17:54:39.624579444+00:00  sys.gps.lon -87.995082
# 12876 2025-02-20 17:56:39.212026575+00:00  sys.gps.lon -87.995096
# 12877 2025-02-20 17:58:39.724472894+00:00  sys.gps.lon -87.995073
# 12878 2025-02-20 18:00:39.813819690+00:00  sys.gps.lon -87.995057
# 12879 2025-02-20 18:02:38.941138068+00:00  sys.gps.lon -87.995096
#
#                         meta.host         meta.node meta.vsn
# 0      000048b02d35a87e.ws-nxcore  000048b02d35a87e     W08E
# 1      000048b02d35a87e.ws-nxcore  000048b02d35a87e     W08E
# 2      000048b02d35a87e.ws-nxcore  000048b02d35a87e     W08E
# 3      000048b02d35a87e.ws-nxcore  000048b02d35a87e     W08E
# 4      000048b02d35a87e.ws-nxcore  000048b02d35a87e     W08E
# ...                           ...               ...      ...
# 12875  000048b02dd3c76e.ws-nxcore  000048b02dd3c76e     W0A4
# 12876  000048b02dd3c76e.ws-nxcore  000048b02dd3c76e     W0A4
# 12877  000048b02dd3c76e.ws-nxcore  000048b02dd3c76e     W0A4
# 12878  000048b02dd3c76e.ws-nxcore  000048b02dd3c76e     W0A4
# 12879  000048b02dd3c76e.ws-nxcore  000048b02dd3c76e     W0A4
#
# [12880 rows x 6 columns]

# %% [markdown]
# ## Display the Map

# %%
for node in node_list:
    node_df = df[df['meta.vsn'] == node]
    if not node_df.empty:
        values = node_df.groupby("name").value.mean()
        lat = values.get("sys.gps.lat")
        lon = values.get("sys.gps.lon")

        if lat is not None and lon is not None:
            # Create a label with the node name
            label = folium.Popup(node, parse_html=True)
            folium.Marker([lat, lon], popup=label).add_to(m)
        else:
            print(f"No GPS data for node: {node}")
    else:
        print(f"No data for node: {node}")

m
# Out:
# No data for node: W0AD
# No data for node: W0AB
# No data for node: W0A5
# No data for node: W0A3
# No data for node: W0A2
# No data for node: W09F
# No data for node: W09E
# No data for node: W09C
# No data for node: W09B
# No data for node: W098
# No data for node: W095
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_993b9976a437280ba4519cecc919d7f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_993b9976a437280ba4519cecc919d7f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_993b9976a437280ba4519cecc919d7f9 = L.map(
#                 &quot;map_993b9976a437280ba4519cecc919d7f9&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aba0c90da9a8951dd4f6b6112d2a33e6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_aba0c90da9a8951dd4f6b6112d2a33e6.addTo(map_993b9976a437280ba4519cecc919d7f9);
#
#
#             tile_layer_aba0c90da9a8951dd4f6b6112d2a33e6.addTo(map_993b9976a437280ba4519cecc919d7f9);
#
#
#             var marker_bd8a2dbfdd6e46199f9c14d7a2791238 = L.marker(
#                 [41.701587684188816, -87.99511856298321],
#                 {}
#             ).addTo(map_993b9976a437280ba4519cecc919d7f9);
#
#
#         var popup_b54b39cc9fcd30535212376b5ef4222d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_512ff4e920dcc490270d91a667cacacc = $(`&lt;div id=&quot;html_512ff4e920dcc490270d91a667cacacc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;W0A4&lt;/div&gt;`)[0];
#                 popup_b54b39cc9fcd30535212376b5ef4222d.setContent(html_512ff4e920dcc490270d91a667cacacc);
#
#
#
#         marker_bd8a2dbfdd6e46199f9c14d7a2791238.bindPopup(popup_b54b39cc9fcd30535212376b5ef4222d)
#         ;
#
#
#
#
#             var marker_ddb54247bced72e02e94c53a46fc17a8 = L.marker(
#                 [41.70142481684578, -87.99526982987987],
#                 {}
#             ).addTo(map_993b9976a437280ba4519cecc919d7f9);
#
#
#         var popup_2e333bed256f9ab7d509bbeca9dac55b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e621e4d46bc2e3bd45bbc15e44673861 = $(`&lt;div id=&quot;html_e621e4d46bc2e3bd45bbc15e44673861&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;W0A1&lt;/div&gt;`)[0];
#                 popup_2e333bed256f9ab7d509bbeca9dac55b.setContent(html_e621e4d46bc2e3bd45bbc15e44673861);
#
#
#
#         marker_ddb54247bced72e02e94c53a46fc17a8.bindPopup(popup_2e333bed256f9ab7d509bbeca9dac55b)
#         ;
#
#
#
#
#             var marker_172fbef3997fa9c14adec729675fbf11 = L.marker(
#                 [41.77701668688317, -87.60974452822114],
#                 {}
#             ).addTo(map_993b9976a437280ba4519cecc919d7f9);
#
#
#         var popup_3db2b2cb43fe173b6266eb9222f94c06 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c79da8b755773cecb2badf47a9d1575 = $(`&lt;div id=&quot;html_1c79da8b755773cecb2badf47a9d1575&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;W0A0&lt;/div&gt;`)[0];
#                 popup_3db2b2cb43fe173b6266eb9222f94c06.setContent(html_1c79da8b755773cecb2badf47a9d1575);
#
#
#
#         marker_172fbef3997fa9c14adec729675fbf11.bindPopup(popup_3db2b2cb43fe173b6266eb9222f94c06)
#         ;
#
#
#
#
#             var marker_34e8ddcbb5fdf1c56cae2c1f8ca7bafe = L.marker(
#                 [41.701457518968056, -87.99528090400972],
#                 {}
#             ).addTo(map_993b9976a437280ba4519cecc919d7f9);
#
#
#         var popup_15cc5ed865bf47e915c2ad6bc4e2828b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e3f1738bb6f34ce343be509a1ed20d57 = $(`&lt;div id=&quot;html_e3f1738bb6f34ce343be509a1ed20d57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;W09D&lt;/div&gt;`)[0];
#                 popup_15cc5ed865bf47e915c2ad6bc4e2828b.setContent(html_e3f1738bb6f34ce343be509a1ed20d57);
#
#
#
#         marker_34e8ddcbb5fdf1c56cae2c1f8ca7bafe.bindPopup(popup_15cc5ed865bf47e915c2ad6bc4e2828b)
#         ;
#
#
#
#
#             var marker_49981d471c9a4081f643e2c7c64bfcc9 = L.marker(
#                 [41.701451639259616, -87.99525297523077],
#                 {}
#             ).addTo(map_993b9976a437280ba4519cecc919d7f9);
#
#
#         var popup_d3e73e8420d49583cd40f2c388dbdd6c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_204dd044346493db3c94753d6d85021f = $(`&lt;div id=&quot;html_204dd044346493db3c94753d6d85021f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;W09A&lt;/div&gt;`)[0];
#                 popup_d3e73e8420d49583cd40f2c388dbdd6c.setContent(html_204dd044346493db3c94753d6d85021f);
#
#
#
#         marker_49981d471c9a4081f643e2c7c64bfcc9.bindPopup(popup_d3e73e8420d49583cd40f2c388dbdd6c)
#         ;
#
#
#
#
#             var marker_6c0269c
